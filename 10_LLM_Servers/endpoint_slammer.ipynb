# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
from langchain_fireworks import ChatFireworks

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
model_endpoint = "accounts/fireworks/models/gpt-oss-20b"

llm = ChatFireworks(model=model_endpoint)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# Got it—here’s the classic answer, with a dash of science and a pinch of curiosity:
#
# ### In the tongue‑twister world
# A woodchuck would **chuck a “reasonable” amount** of wood, nothing too mind‑blowing—just enough to keep the village grindstone busy! The old rhyme ends with a flourish, not a precise number, because “chuck” here is a playful verb.
#
# ### The science‑inspired legend
# Wildlife biologist **Richard Thomas** (1968) tried to quantify the situation. He calculated that if a woodchuck could chuck wood instead of soil, it might move **about 700 pounds (≈320 kg)** of wood in the course of a day. That’s roughly the amount of wood a chipmunk could lift, but huge for a burrowing gopher‑like rodent. Of course, real woodchucks (groundhogs) don’t actually chuck wood—they dig burrows and gnaw on vegetation.
#
# ### Bottom line
# - **Tongue‑twister answer:** “A woodchuck would chuck as much wood as a woodchuck could chuck, all while keeping its luck!”
# - **Playful estimate:** Roughly **700 lb** (if it could turn its burrow‑skills into wood‑pumping prowess).
#
# So, next time you hear the rhyme, you can confidently say: *A woodchuck would chuck about 700 pounds of wood if it was that kind of animal.* And if you’re curious, you can always ask a woodchuck how much wood it *really* likes to gnaw on!

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 25)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Response 4: The classic answer is that a woodchuck would chuck “as much ...
# Response 2: A woodchuck would chuck roughly 700 pounds of wood if it cou...
# Response 21: The age‑old tongue‑twister goes:
#
# > “A wood‑chuck would ch...
# Response 11: Ah, the age‑old tongue‑twister! 🌲🐿️ While there's no one def...
# Response 18: If a woodchuck could actually chuck wood, the tongue‑twister...
# Response 14: A classic riddle with a bit of folklore humor — wood‑chucks ...
# Response 7: The classic tongue‑twister isn’t meant to be a scientific qu...
# Response 15: **Short answer:**
# A wood‑chuck could chuck **about 700 pou...
# Response 13: If a woodchuck could actually chuck wood, the consensus esti...
# Response 23: Ah, the classic tongue‑twister!  The short answer is that a ...
# Response 8: **Answer (classic tongue‑twister style):**
# > **He would ch...
# Response 22: The classic tongue‑twister doesn’t have an official answer—i...
# Response 3: **Answer:**
#
# > **“A woodchuck would chuck as much wood as a ...
# Response 19: It’s one of those classic “tongue‑twisters” that has stuck a...
# Response 5: **The Rock‑n’Roll**
#
# > *“How much wood could a wood‑chuck ch...
# Response 17: It’s a classic tongue‑twister joke, not a serious physics pr...
# Response 24: **Your 24th request—*“How much wood could a wood‑chuck chuck...
# Response 20: A classic tongue‑twister (and a playful piece of folklore) f...
# Response 6: **A quick answer:**
# A real woodchuck would *probably* chuc...
# Response 9: ### The Classic Answer (Tongue‑Twister 101)
#
# > “How much woo...
# Response 12: **Answer (Request 12)**
# The classic tongue‑twister simply ...
# Response 1: **Answer (classic folkloric wisdom)**
# > *“A wood‑chuck wou...
# Response 16: Ah, the classic riddle that’s been debated by linguists, com...
# Response 10: **Short answer:**
# There’s no scientific “maximum” for a wo...
